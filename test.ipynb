# %%
from GoL_utils import *

a = array([[0,0,0],[0,1,1],[1,0,0]])
name = grid_to_name(a)

# %%
# %%timeit
grid_to_hex(a)
# Out:
# 4.41 µs ± 103 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
# %%timeit
grid_to_name(a)
# Out:
# 4.8 µs ± 33 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
# %%timeit
name_to_grid(name)
# Out:
# Hexa = 0e
# Int = 14
# Bin = 6
# Len(res) = 9
# Len(bin) = 4
# Hexa = 0e
# Int = 14
# Bin = 6
# Len(res) = 9
# Len(bin) = 4
# Hexa = 0e
# Int = 14
# Bin = 6
# Len(res) = 9
# Len(bin) = 4
# Hexa = 0e
# Int = 14
# Bin = 6
# Len(res) = 9
# Len(bin) = 4
# Hexa = 0e
# Int = 14
# Bin = 6
# Len(res) = 9
# Len(bin) = 4
# Hexa = 0e
# Int = 14
# Bin = 6
# Len(res) = 9
# Len(bin) = 4
# Hexa = 0e
# Int = 14
# Bin = 6
# Len(res) = 9
# Len(bin) = 4
# Hexa = 0e
# Int = 14
# Bin = 6
# Len(res) = 9
# Len(bin) = 4
# Hexa = 0e
# Int = 14
# Bin = 6
# Len(res) = 9
# Len(bin) = 4
# Hexa = 0e
# Int = 14
# Bin = 6
# Len(res) = 9
# Len(bin) = 4
# Hexa = 0e
# Int = 14
# Bin = 6
# Len(res) = 9
# Len(bin) = 4
# Hexa = 0e
# Int = 14
# Bin = 6
# Len(res) = 9
# Len(bin) = 4
# Hexa = 0e
# Int = 14
# Bin = 6
# Len(res) = 9
# Len(bin) = 4
# Hexa = 0e
# Int = 14
# Bin = 6
# Len(res) = 9
# Len(bin) = 4
# Hexa = 0e
# Int = 14
# Bin = 6
# Len(res) = 9
# Len(bin) = 4
# Hexa = 0e
# Int = 14
# Bin = 6
# Len(res) = 9
# ...

# %%
import matplotlib.pyplot as plt
from GoL_utils import *
import numpy as np

print(bin(int("...",16)))

grid = name_to_grid("51x51_...")

N,M = grid.shape
np.savetxt("yolo.npy",grid.astype(int),fmt="%d")

plt.figure(figsize=(10,10))
plt.pcolor(range(N),range(M),grid, shading='auto', cmap="CMRmap")
plt.colorbar(label='Total living time of cell')
plt.title("Vitality")
# Out:
# ...
# Hexa = ...
# Int = ...
# Bin = 2596
# Len(res) = 2601
# Len(bin) = 2594
# Text(0.5, 1.0, 'Vitality')
